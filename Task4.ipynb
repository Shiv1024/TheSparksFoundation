# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d=pd.read_csv("/content/globalterrorismdb.csv",encoding='latin1')
d
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 111585  201210140004   2012      10    14        NaN         0        NaN
# 111586  201210140005   2012      10    14        NaN         1        NaN
# 111587  201210140006   2012      10    14        NaN         0        NaN
# 111588  201210140007   2012      10    14        NaN         0        NaN
# 111589  201210140008   2012      10    14        NaN         0        NaN
#
#         country         country_txt  region  ...  \
# 0            58  Dominican Republic       2  ...
# 1           130              Mexico       1  ...
# 2           160         Philippines       5  ...
# 3            78              Greece       8  ...
# 4           101               Japan       4  ...
# ...         ...                 ...     ...  ...
# 111585      153            Pakistan       6  ...
# 111586      146               Niger      11  ...
# 111587      147             Nigeria      11  ...
# 111588       92               India       6  ...
# 111589      153            Pakistan       6  ...
#
#                                                  addnotes  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 111585  The civilian victims were identified as Muhamm...
# 111586  The victims also went on to state that MUJAO w...
# 111587                                                NaN
# 111588                                                NaN
# 111589                                                NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 111585  "Pakistan: Two killed in Quetta   firing," Rig...
# 111586  "Aid workers kidnapped in Niger freed: NGOs," ...
# 111587  "Blast strikes near military patrol in norther...
# 111588  "Militants hurl bomb at MLA's private house, n...
# 111589                                                NaN
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 111585  "One killed, three injured in Quetta   firing,...
# 111586  "Kidnapped aid workers released in Niger, one ...
# 111587  "Blast strikes near military patrol in norther...
# 111588  "Life comes to a halt due to observation of Na...
# 111589                                                NaN
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 111585  "2 killed, 3 injured in Quetta   shooting   in...
# 111586  "Niger kidnappers were looking for Italian: of...
# 111587  "JTF Confirms   Bomb Blast   in Maiduguri," Le...
# 111588                                                NaN
# 111589                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS      0.0       0.0      0.0     0.0      NaN
# 1                           PGIS      0.0       1.0      1.0     1.0      NaN
# 2                           PGIS     -9.0      -9.0      1.0     1.0      NaN
# 3                           PGIS     -9.0      -9.0      1.0     1.0      NaN
# 4                           PGIS     -9.0      -9.0      1.0     1.0      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 111585  START Primary Collection      0.0       0.0      0.0     0.0      NaN
# 111586  START Primary Collection      0.0       1.0      1.0     1.0      NaN
# 111587  START Primary Collection     -9.0      -9.0      0.0    -9.0      NaN
# 111588  START Primary Collection     -9.0      -9.0      0.0    -9.0      NaN
# 111589                       NaN      NaN       NaN      NaN     NaN      NaN
#
# [111590 rows x 135 columns]

# %%
d.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.115900e+05  111590.000000  111590.000000  111590.000000
# mean   1.995036e+11    1994.969845       6.418236      15.305520
# std    1.151472e+09      11.515095       3.359510       8.818965
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.986042e+11    1986.000000       4.000000       8.000000
# 50%    1.994040e+11    1994.000000       6.000000      15.000000
# 75%    2.007063e+11    2007.000000       9.000000      23.000000
# max    2.012101e+11    2012.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  111590.000000  111590.000000  111590.000000  107473.000000
# mean        0.033650     136.752164       6.470311      21.676979
# std         0.180327     122.261507       3.065989      21.155825
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      65.000000       3.000000       7.716666
# 50%         0.000000      98.000000       6.000000      28.585836
# 75%         0.000000     167.000000      10.000000      36.021140
# max         1.000000    1004.000000      12.000000      74.633553
#
#           longitude    specificity  ...     ransomamt   ransomamtus  \
# count  1.074720e+05  111584.000000  ...  9.850000e+02  1.990000e+02
# mean  -7.894285e+02       1.429847  ...  3.422270e+06  9.245136e+05
# std    2.628988e+05       1.042421  ...  3.380766e+07  7.349934e+06
# min   -8.618590e+07       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%   -7.050530e+01       1.000000  ...  0.000000e+00  0.000000e+00
# 50%    2.962306e+01       1.000000  ...  1.000000e+04  0.000000e+00
# 75%    6.714331e+01       1.000000  ...  5.000000e+05  0.000000e+00
# max    1.793667e+02       5.000000  ...  1.000000e+09  1.000000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome    nreleased        INT_LOG  \
# count  4.100000e+02    188.000000     5149.000000  4557.000000  111589.000000
# mean   6.245445e+05    653.654255        4.438143   -21.368664      -4.378514
# std    3.153400e+06   4969.053115        2.058373    60.799128       4.549350
# min   -9.900000e+01    -99.000000        1.000000   -99.000000      -9.000000
# 25%   -9.900000e+01      0.000000        2.000000   -99.000000      -9.000000
# 50%    0.000000e+00      0.000000        4.000000     1.000000       0.000000
# 75%    3.850000e+04      0.000000        7.000000     2.000000       0.000000
# max    4.100000e+07  48000.000000        7.000000  1201.000000       1.000000
#
#             INT_IDEO       INT_MISC        INT_ANY
# count  111589.000000  111589.000000  111589.000000
# mean       -4.336395       0.106668      -3.676258
# std         4.605674       0.698624       4.654687
# min        -9.000000      -9.000000      -9.000000
# 25%        -9.000000       0.000000      -9.000000
# 50%         0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]

# %%
d.shape
# Out:
# (111590, 135)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111590 entries, 0 to 111589
# Columns: 135 entries, eventid to related
# dtypes: float64(60), int64(17), object(58)
# memory usage: 114.9+ MB

# %%
year=d['iyear'].unique()
year_count=d['iyear'].value_counts(dropna=False).sort_index()
plt.figure(figsize=(19,11))
sns.barplot(x=year,y=year_count,palette="tab10")
plt.xticks(rotation=50)
plt.xlabel('Attacking year',fontsize=20)
plt.ylabel('no. of attacks in that year',fontsize=20)
plt.title('Attacks in Year',fontsize=50)
plt.show()

# %%
pd.crosstab(d.iyear,d.region_txt).plot(kind='area',stacked=False,figsize=(20,10))
plt.title('Terrorist Activities by ragion in a year',fontsize=20)
plt.xlabel('year',fontsize=20)
plt.ylabel('No.of attacks',fontsize=20)
plt.show()

# %%
attack=d.country_txt.value_counts()[:20]
attack
# Out:
# Iraq              9044
# Colombia          7546
# India             7425
# Pakistan          6761
# Peru              6053
# El Salvador       5320
# United Kingdom    4640
# Afghanistan       4266
# Philippines       3561
# Spain             3232
# Turkey            2980
# Sri Lanka         2939
# Algeria           2667
# United States     2619
# France            2532
# Chile             2312
# Thailand          2106
# Guatemala         2044
# Lebanon           2041
# Nicaragua         1968
# Name: country_txt, dtype: int64

# %%
d.gname.value_counts()[1:10]
# Out:
# Shining Path (SL)                                   4524
# Farabundo Marti National Liberation Front (FMLN)    3351
# Irish Republican Army (IRA)                         2671
# Taliban                                             2317
# Revolutionary Armed Forces of Colombia (FARC)       2119
# Basque Fatherland and Freedom (ETA)                 2024
# Liberation Tigers of Tamil Eelam (LTTE)             1606
# Communist Party of India - Maoist (CPI-Maoist)      1465
# New People's Army (NPA)                             1399
# Name: gname, dtype: int64

# %%
plt.subplots(figsize=(20,10))
sns.barplot(d['country_txt'].value_counts()[:10].index,d['country_txt'].value_counts()[:10].values,palette='YlOrBr_r')
plt.title('Top countries Affected')
plt.xlabel('Countries')
plt.ylabel('Attacks')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df = d[['iyear','nkill']].groupby(['iyear']).sum()
fig, ax4 = plt.subplots(figsize=(20,10))
df.plot(kind='bar',alpha=0.7,ax=ax4)
plt.xticks(rotation = 50)
plt.title("People Died Due To Attack",fontsize=25)
plt.ylabel("Number of killed peope",fontsize=20)
plt.xlabel('Year',fontsize=20)
top_side = ax4.spines["top"]
top_side.set_visible(False)
right_side = ax4.spines["right"]
right_side.set_visible(False)

# %%
d['city'].value_counts().to_frame().sort_values('city',axis=0,ascending=False).head(10).plot(kind='bar',figsize=(20,10),color='red')
plt.xticks(rotation = 50)
plt.xlabel("City",fontsize=15)
plt.ylabel("Number of attack",fontsize=15)
plt.title("Top 10 most effected city",fontsize=20)
plt.show()

# %%
d[['attacktype1_txt','nkill']].groupby(["attacktype1_txt"],axis=0).sum().plot(kind='bar',figsize=(20,10),color=['darkslateblue'])
plt.xticks(rotation=50)
plt.title("Number of killed ",fontsize=20)
plt.ylabel('Number of people',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.show()

# %%
d[['attacktype1_txt','nwound']].groupby(["attacktype1_txt"],axis=0).sum().plot(kind='bar',figsize=(20,10),color=['cyan'])
plt.xticks(rotation=50)
plt.title("Number of wounded  ",fontsize=20)
plt.ylabel('Number of people',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.show()

# %%
plt.subplots(figsize=(20,10))
sns.countplot(d["targtype1_txt"],order=d['targtype1_txt'].value_counts().index,palette="gist_heat",edgecolor=sns.color_palette("mako"));
plt.xticks(rotation=90)
plt.xlabel("Attacktype",fontsize=15)
plt.ylabel("count",fontsize=15)
plt.title("Attack per year",fontsize=20)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
d[['gname','nkill']].groupby(['gname'],axis=0).sum().drop('Unknown').sort_values('nkill',ascending=False).head(10).plot(kind='bar',color='yellow',figsize=(20,10))
plt.title("Top 10 terrorist group attack",fontsize=20)
plt.xlabel("terrorist group name",fontsize=15)
plt.ylabel("No of killed people",fontsize=15)
plt.show()

# %%
df=d[['gname','country_txt','nkill']]
df=df.groupby(['gname','country_txt'],axis=0).sum().sort_values('nkill',ascending=False).drop('Unknown').reset_index().head(10)
df
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:4150: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#                                               gname  country_txt    nkill
# 0                                 Shining Path (SL)         Peru  11569.0
# 1           Liberation Tigers of Tamil Eelam (LTTE)    Sri Lanka  10928.0
# 2  Farabundo Marti National Liberation Front (FMLN)  El Salvador   8019.0
# 3                                           Taliban  Afghanistan   6928.0
# 4                 Nicaraguan Democratic Force (FDN)    Nicaragua   6630.0
# 5     Revolutionary Armed Forces of Colombia (FARC)     Colombia   5377.0
# 6                    Kurdistan Workers' Party (PKK)       Turkey   3722.0
# 7                                  Al-Qaida in Iraq         Iraq   3713.0
# 8                           New People's Army (NPA)  Philippines   3518.0
# 9                   Tehrik-i-Taliban Pakistan (TTP)     Pakistan   3362.0

# %%
kill = d.loc[:,'nkill']
print('Number of people killed by terror attack:', int(sum(kill.dropna())))
# Out:
# Number of people killed by terror attack: 242172

# %%
typeKill = d.pivot_table(columns='attacktype1_txt', values='nkill', aggfunc='sum')
typeKill
# Out:
# attacktype1_txt  Armed Assault  Assassination  Bombing/Explosion  \
# nkill                 109431.0        20014.0            83038.0
#
# attacktype1_txt  Facility/Infrastructure Attack  Hijacking  \
# nkill                                    2675.0     3572.0
#
# attacktype1_txt  Hostage Taking (Barricade Incident)  \
# nkill                                         1875.0
#
# attacktype1_txt  Hostage Taking (Kidnapping)  Unarmed Assault  Unknown
# nkill                                 5587.0            703.0  15277.0

# %%
countryKill = d.pivot_table(columns='country_txt', values='nkill', aggfunc='sum')
countryKill
# Out:
# country_txt  Afghanistan  Albania  Algeria  Andorra  Angola  \
# nkill            11252.0     41.0  10882.0      0.0  3036.0
#
# country_txt  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  ...  \
# nkill                        0.0      490.0     31.0       13.0     28.0  ...
#
# country_txt  Vietnam  Wallis and Futuna  West Bank and Gaza Strip  \
# nkill            1.0                0.0                    1157.0
#
# country_txt  West Germany (FRG)  Western Sahara   Yemen  Yugoslavia  Zaire  \
# nkill                      97.0             1.0  2067.0       119.0  324.0
#
# country_txt  Zambia  Zimbabwe
# nkill          70.0     153.0
#
# [1 rows x 205 columns]

# %% [markdown]
# **Conclusion Ans Results**
#
#
# * Country with the most attacks: Iraq
#
# *  City with the most attacks: Baghdad
#
# *  Region with the most attacks: South Asia
# *  Year with the most attacks: 2012
#
# *   Group with the most attacks: Shining Path (SL)
#
#
# *   Most Attack Types: Armed Assault
#
#
# **Thank You**
